# %% [markdown]
# ## Insights
#
# 1. Tesla deliveries increased over time.
# 2. Production rose significantly after 2020.
# 3. Model 3 shows highest deliveries.
# 4. North America contributes major production.
# 5. Deliveries and production are positively correlated.

# %% [markdown]
# # Conclusion
#
# The analysis shows Tesla experienced strong growth in deliveries and production between 2015 and 2025.
#
# Key findings:
# - Deliveries increased over the years
# - Production capacity expanded significantly
# - Model 3 and Model Y performed strongly
# - Regional demand remained high in North America and Europe
#
# This indicates Tesla’s growing global EV market dominance.

# %%
# Graph 5: Correlation heatmap

plt.figure(figsize=(10,8))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Graph 4: Model comparison

plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Model', y='Estimated_Deliveries')
plt.title("Deliveries by Model")
plt.xticks(rotation=45)
plt.show()

# %%
#Graph 3: Region comparison

plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Region', y='Estimated_Deliveries')
plt.title("Deliveries by Region")
plt.xticks(rotation=45)
plt.show()

# %%
#Graph 2: Production by year

plt.figure(figsize=(10,5))
sns.lineplot(data=df, x='Year', y='Production_Units')
plt.title("Tesla Production Over Years")
plt.show()

# %%
#Graph 1: Deliveries by year

plt.figure(figsize=(10,5))
sns.lineplot(data=df, x='Year', y='Estimated_Deliveries')
plt.title("Tesla Deliveries Over Years")
plt.show()

# %%
df.drop_duplicates(inplace=True)
print("Duplicates removed")
# Out:
# Duplicates removed

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month                   0
# Region                  0
# Model                   0
# Estimated_Deliveries    0
# Production_Units        0
# Avg_Price_USD           0
# Battery_Capacity_kWh    0
# Range_km                0
# CO2_Saved_tons          0
# Source_Type             0
# Charging_Stations       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  2640 non-null   int64
#  1   Month                 2640 non-null   int64
#  2   Region                2640 non-null   object
#  3   Model                 2640 non-null   object
#  4   Estimated_Deliveries  2640 non-null   int64
#  5   Production_Units      2640 non-null   int64
#  6   Avg_Price_USD         2640 non-null   float64
#  7   Battery_Capacity_kWh  2640 non-null   int64
#  8   Range_km              2640 non-null   int64
#  9   CO2_Saved_tons        2640 non-null   float64
#  10  Source_Type           2640 non-null   object
#  11  Charging_Stations     2640 non-null   int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 247.6+ KB

# %%
df = pd.read_csv("tesla_deliveries_dataset_2015_2025.csv")
df.head()
# Out:
#    Year  Month         Region    Model  Estimated_Deliveries  \
# 0  2023      5         Europe  Model S                 17646
# 1  2015      2           Asia  Model X                  3797
# 2  2019      1  North America  Model X                  8411
# 3  2021      2  North America  Model 3                  6555
# 4  2016     12    Middle East  Model Y                 12374
#
#    Production_Units  Avg_Price_USD  Battery_Capacity_kWh  Range_km  \
# 0             17922       92874.27                   120       704
# 1              4164       62205.65                    75       438
# 2              9189      117887.32                    82       480
# 3              7311       89294.91                   120       712
# 4             13537      114846.78                   120       661
#
#    CO2_Saved_tons           Source_Type  Charging_Stations
# 0         1863.42  Interpolated (Month)              12207
# 1          249.46    Official (Quarter)               7640
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
